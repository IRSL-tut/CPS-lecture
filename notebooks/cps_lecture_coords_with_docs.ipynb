# %%
exec(open('/choreonoid_ws/install/share/irsl_choreonoid/sample/irsl_import.py').read())

# %%
di = DrawInterface()

# %%
vis_cds = mkshapes.makeCoords(length=0.35, lineWidth=6)
cds = coordinates()

# %%
di.addObject(vis_cds)
di.addObject(mkshapes.makeCoords())

# %% [markdown]
# ## プロパティ
# https://irsl-tut.github.io/irsl_documents/ja/coordinates.html#properties

# %% [markdown]
# #### pos

# %%
cds.pos
# Out:
# array([0., 0., 0.])

# %%
cds.pos = fv(0.5, -0.5, 1.0)

# %%
cds
# Out:
# <coordinates[0x558be9bdcac0] 0.5 -0.5 1 / 0 0 0 1 >

# %%
vis_cds.newcoords(cds)
# Out:
# Wrap: <coordinates[0x558be9c2ff30] 0.5 -0.5 1 / 0 0 0 1 > | <cnoid.Util.SgPosTransform object at 0x797775538bb0>

# %% [markdown]
# #### rot

# %%
cds.rot
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
cds.rot = fv([0, 1, 0],[1, 0, 0],[0, 0, -1])

# %%
vis_cds.newcoords(cds)
# Out:
# Wrap: <coordinates[0x558be9c2ff30] 0.5 -0.5 1 / 0.707107 0.707107 0 0 > | <cnoid.Util.SgPosTransform object at 0x797775538bb0>

# %% [markdown]
# #### x_axis

# %%
cds.x_axis
# Out:
# array([0., 1., 0.])

# %% [markdown]
# #### y_axis

# %%
cds.y_axis
# Out:
# array([1., 0., 0.])

# %% [markdown]
# #### z_axis

# %%
cds.z_axis
# Out:
# array([ 0.,  0., -1.])

# %% [markdown]
# #### quaternion

# %%
cds.quaternion
# Out:
# array([0.70710678, 0.70710678, 0.        , 0.        ])

# %%
cds.quaternion = fv(0, 0, 0, 1.0)

# %%
vis_cds.newcoords(cds)
# Out:
# Wrap: <coordinates[0x558be9c2ff30] 0.5 -0.5 1 / 0 0 0 1 > | <cnoid.Util.SgPosTransform object at 0x797775538bb0>

# %% [markdown]
# #### RPY

# %%
cds.RPY
# Out:
# array([ 0., -0.,  0.])

# %%
cds.RPY = fv(0, 0, -0.8)

# %%
vis_cds.newcoords(cds)
# Out:
# Wrap: <coordinates[0x558be9c2ff30] 0.5 -0.5 1 / 0 0 -0.389418 0.921061 > | <cnoid.Util.SgPosTransform object at 0x797775538bb0>

# %% [markdown]
# #### angleAxis

# %%
cds.angleAxis
# Out:
# array([ 0. ,  0. , -1. ,  0.8])

# %%
cds.angleAxis = fv(1, 0, 0, 1.2)

# %%
cds
# Out:
# <coordinates[0x558be9bdcac0] 0.5 -0.5 1 / 0.564642 0 0 0.825336 >

# %%
vis_cds.newcoords(cds)
# Out:
# Wrap: <coordinates[0x558be9c2ff30] 0.5 -0.5 1 / 0.564642 0 0 0.825336 > | <cnoid.Util.SgPosTransform object at 0x797775538bb0>

# %% [markdown]
# #### homogeneousTransformation

# %%
cds.cnoidPosition
# Out:
# array([[ 1.        ,  0.        ,  0.        ,  0.5       ],
#        [ 0.        ,  0.36235775, -0.93203909, -0.5       ],
#        [ 0.        ,  0.93203909,  0.36235775,  1.        ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])

# %%
cds.cnoidPosition = fv([0, 1, 0, -0.5],[1, 0, 0, -0.5],[0, 0, -1, 0], [0, 0, 0, 1])

# %%
cds
# Out:
# <coordinates[0x558be9bdcac0] -0.5 -0.5 0 / 0.707107 0.707107 0 0 >

# %%
vis_cds.newcoords(cds)
# Out:
# Wrap: <coordinates[0x558be9c2ff30] -0.5 -0.5 0 / 0.707107 0.707107 0 0 > | <cnoid.Util.SgPosTransform object at 0x797775538bb0>

# %% [markdown]
# ## 変換したベクトルを返すメソッド(元のベクトルを変更しない)
# https://irsl-tut.github.io/irsl_documents/ja/coordinates.html#methods-to-convert-a-vector

# %%
cds.RPY = fv(0.5, -0.5, 1)
cds.pos = fv(0.4, -0.3, 0.8)
cds
# Out:
# <coordinates[0x558be9bdcac0] 0.4 -0.3 0.8 / 0.325292 -0.0954433 0.503796 0.794522 >

# %% [markdown]
# #### rotate_vector

# %%
v = fv(1., 1., 1.)
res0 = cds.rotate_vector(v)
v
# Out:
# array([1., 1., 1.])

# %%
res0
# Out:
# array([-0.21238992,  0.40613758,  1.67031218])

# %% [markdown]
# #### invese_rotate_vector

# %%
v = fv(1., 1., 1.)
res1 = cds.inverse_rotate_vector(v)
v
# Out:
# array([1., 1., 1.])

# %%
res1
# Out:
# array([ 1.69204568, -0.16116389,  0.33317804])

# %%
cds.inverse_rotate_vector(res0)
# Out:
# array([1., 1., 1.])

# %% [markdown]
# #### transform_vector

# %%
v = fv(0.1, 0.2, 0.3)
res0 = cds.transform_vector(v)
v
# Out:
# array([0.1, 0.2, 0.3])

# %%
res0
# Out:
# array([0.92771586, 1.94607435, 3.363135  ])

# %% [markdown]
# #### inverse_transform_vector

# %%
v = fv(0.1, 0.2, 0.3)
res1 = cds.inverse_transform_vector(v)
v
# Out:
# array([0.1, 0.2, 0.3])

# %%
res1
# Out:
# array([-3.05042132, -0.86495026, -1.13436802])

# %%
cds.inverse_transform_vector(res0)
# Out:
# array([0.1, 0.2, 0.3])

# %% [markdown]
# ## ベクトルを座標系を使って変換するメソッド（元のベクトルを変更する）
# https://irsl-tut.github.io/irsl_documents/ja/coordinates.html#methods-to-convert-a-vector-change-input-value

# %% [markdown]
# #### rotateVector

# %%
v = fv(1., 1., 1.)
res0 = cds.rotateVector(v)
v
# Out:
# array([-0.21238992,  0.40613758,  1.67031218])

# %% [markdown]
# #### inverseRotateVector

# %%
v = fv(1., 1., 1.)
res1 = cds.inverseRotateVector(v)
v
# Out:
# array([ 1.69204568, -0.16116389,  0.33317804])

# %%
cds.inverseRotateVector(res0)
# Out:
# array([1., 1., 1.])

# %%
res0
# Out:
# array([1., 1., 1.])

# %% [markdown]
# #### transformVector

# %%
v = fv(1., 1., 1.)
res0 = cds.transformVector(v)
v
# Out:
# array([0.78761008, 2.40613758, 4.67031218])

# %% [markdown]
# #### inverseTransformVector

# %%
v = fv(1., 1., 1.)
res1 = cds.inverseTransformVector(v)
v
# Out:
# array([-1.69731134, -1.12221973, -0.92723087])

# %%
cds.inverseTransformVector(res0)
# Out:
# array([1., 1., 1.])

# %%
res0
# Out:
# array([1., 1., 1.])

# %% [markdown]
# ## 座標系を返すメソッド(自身のインスタンスの値を変更しない)
# https://irsl-tut.github.io/irsl_documents/ja/coordinates.html#methods-to-return-a-coordinate-without-modifying-itself

# %% [markdown]
# #### inverse_transformation

# %%
cds.inverse_transformation()
# Out:
# <coordinates[0x558be8afef00] -3.38936 -0.961056 -1.26041 / -0.325292 0.0954433 -0.503796 0.794522 >

# %%
cds.inverse_transformation().transform(cds)
# Out:
# <coordinates[0x558be8625e90] 0 0 0 / 0 0 0 1 >

# %% [markdown]
# #### transformation

# %%
cds2 = coordinates(fv(0.5, 0.5, 0.5), fv(0, math.sqrt(0.5), math.sqrt(0.5), 0))

# %%
cds.transformation(cds2)
# Out:
# <coordinates[0x558be6f8b230] -2.86602 0.0423543 -3.4328 / 0.423726 0.791828 0.331795 0.288749 >

# %%
cds.get_transformed(cds.transformation(cds2))
# Out:
# <coordinates[0x558be87e3a70] -1 2 -1 / 5.55112e-17 0.707107 0.707107 1.11022e-16 >

# %% [markdown]
# #### mid_coords

# %%
cds.mid_coords(0.5, cds2)
# Out:
# <coordinates[0x558be9da1dc0] 0 2 1 / 0.202616 0.38099 0.754241 0.494888 >

# %% [markdown]
# #### get_transformed

# %%
cds.get_transformed(cds2)
# Out:
# <coordinates[0x558be880cc30] -1.37555 2.43611 2.59189 / -0.423726 0.331795 0.791828 -0.288749 >

# %%
cds.get_transformed(cds2).transform(cds2.inverse_transformation()).equal(cds)
# Out:
# True

# %% [markdown]
# ## 自身のインスタンスの値を変更するメソッド
# https://irsl-tut.github.io/irsl_documents/ja/coordinates.html#methods-to-modify-itself

# %% [markdown]
# #### newcoords

# %%
cds2.newcoords(cds)
# Out:
# <coordinates[0x558be8242d80] 0.4 -0.3 0.8 / 0.325292 -0.0954433 0.503796 0.794522 >

# %%
cds2.equal(cds)
# Out:
# True

# %% [markdown]
# #### move_to

# %% [markdown]
# #### translate

# %%
vis_cds.newcoords(cds2)
# Out:
# Wrap: <coordinates[0x558be9c2ff30] 0.4 -0.3 0.8 / 0.325292 -0.0954433 0.503796 0.794522 > | <cnoid.Util.SgPosTransform object at 0x797775538bb0>

# %%
cds2.translate(fv(0, 0, 0.5))
# Out:
# <coordinates[0x558be8242d80] 0.488049 -0.606536 1.18508 / 0.325292 -0.0954433 0.503796 0.794522 >

# %%
vis_cds.newcoords(cds2)
# Out:
# Wrap: <coordinates[0x558be9c2ff30] 0.488049 -0.606536 1.18508 / 0.325292 -0.0954433 0.503796 0.794522 > | <cnoid.Util.SgPosTransform object at 0x797775538bb0>

# %%
cds2.newcoords(cds)
vis_cds.newcoords(cds2)
# Out:
# Wrap: <coordinates[0x558be9c2ff30] 0.4 -0.3 0.8 / 0.325292 -0.0954433 0.503796 0.794522 > | <cnoid.Util.SgPosTransform object at 0x797775538bb0>

# %%
cds2.translate(fv(0, 0, 0.5), wrt=coordinates.wrt.world)
# Out:
# <coordinates[0x558be8242d80] 0.4 -0.3 1.3 / 0.325292 -0.0954433 0.503796 0.794522 >

# %%
vis_cds.newcoords(cds2)
# Out:
# Wrap: <coordinates[0x558be9c2ff30] 0.4 -0.3 1.3 / 0.325292 -0.0954433 0.503796 0.794522 > | <cnoid.Util.SgPosTransform object at 0x797775538bb0>

# %% [markdown]
# #### locate

# %% [markdown]
# #### rotate

# %%
cds2.rotate(1.0, coordinates.Z)
# Out:
# <coordinates[0x558be8242d80] 0.4 -0.3 1.3 / 7.67389e-17 -0.339005 0.904222 -0.259728 >

# %%
vis_cds.newcoords(cds2)
# Out:
# Wrap: <coordinates[0x558be9c2ff30] 0.4 -0.3 1.3 / 7.67389e-17 -0.339005 0.904222 -0.259728 > | <cnoid.Util.SgPosTransform object at 0x797775538bb0>

# %%
cds2.rotate(0.5, coordinates.X, wrt = coordinates.wrt.world)
# Out:
# <coordinates[0x558be8242d80] 0.4 -0.3 1.3 / 0.00616776 0.453772 -0.574607 0.681087 >

# %%
vis_cds.newcoords(cds2)
# Out:
# Wrap: <coordinates[0x558be9c2ff30] 0.4 -0.3 1.3 / 0.00616776 0.453772 -0.574607 0.681087 > | <cnoid.Util.SgPosTransform object at 0x797775538bb0>

# %% [markdown]
# #### rotate_with_matrix

# %% [markdown]
# #### orient

# %% [markdown]
# #### orient_with_matrix

# %% [markdown]
# #### inverse

# %%
cpy_cds = cds.copy()

# %%
cds.inverse()
# Out:
# <coordinates[0x558be9bdcac0] -0.351666 0.0926955 -0.870482 / -0.325292 0.0954433 -0.503796 0.794522 >

# %%
cpy_cds.transform(cds)
# Out:
# <coordinates[0x558be9d588c0] -1.11022e-16 5.55112e-17 0 / 0 0 0 1 >

# %% [markdown]
# #### transform
