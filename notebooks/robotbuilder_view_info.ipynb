# %% [markdown]
# # RobotBuilder でロボットモデルを可視化

# %% [markdown]
# インポート(IRSL標準)

# %%
exec(open('/choreonoid_ws/install/share/irsl_choreonoid/sample/irsl_import.py').read())

# %% [markdown]
# ## ロボットモデルの選択
# bodyファイルを指定する。
#
# コメントアウトしている他のファイルを選択すると、別のbodyを見ることができる

# %%
fname=iu.parseURL('choreonoid://share/model/HRP4C/HRP4C.body')
#fname=iu.parseURL('choreonoid://share/model/AizuSpider/AizuSpiderSS.body')
#fname=iu.parseURL('choreonoid://share/model/WAREC1/WAREC1.body')
#fname=iu.parseURL('choreonoid://share/model/PA10/PA10.body')
#fname=iu.parseURL('choreonoid://share/model/UniversalRobots/UR5.body')

# %% [markdown]
# ## ロボットモデルのロード

# %%
rb=RobotBuilder(robot=fname)

# %% [markdown]
# ## モデルのビジュアライズ

# %%
rb.viewInfo()
# Out:
# [Wrap: <coordinates[0x55e04ac51200] 0 0 0.784 / 0 0 0 1 > | <cnoid.Util.SgPosTransform object at 0x7fa484315d30>, Wrap: <coordinates[0x55e025676080] 0 0.0875 0.784 / 0 0 0 1 > | <cnoid.Util.SgPosTransform object at 0x7fa484300470>, Wrap: <coordinates[0x55e025670070] 0 0.0875 0.784 / 0 0 0 1 > | <cnoid.Util.SgPosTransform object at 0x7fa4844700f0>, Wrap: <coordinates[0x55e0201e8000] 0 0.0875 0.784 / 0 0 0 1 > | <cnoid.Util.SgPosTransform object at 0x7fa484479030>, Wrap: <coordinates[0x55e025650400] 0 0.06845 0.434 / 0 0 0 1 > | <cnoid.Util.SgPosTransform object at 0x7fa48446d930>, Wrap: <coordinates[0x55e0256627a0] 0 0.06845 0.092849 / 0 0 0 1 > | <cnoid.Util.SgPosTransform object at 0x7fa4840c91f0>, Wrap: <coordinates[0x55e04ac523c0] 0 0.06845 0.092849 / 0 0 0 1 > | <cnoid.Util.SgPosTransform object at 0x7fa4840af9b0>, Wrap: <coordinates[0x55e04ac81730] 0.115 0.06845 0.015849 / 0 0 0 1 > | <cnoid.Util.SgPosTransform object at 0x7fa484096670>, Wrap: <coordinates[0x55e04ac93ce0] 0 -0.0
# ...

# %% [markdown]
# viewAll / 全体が見える位置にカメラを移動

# %%
rb.draw.viewAll()

# %% [markdown]
# 表示画面

# %%
# %display

# %% [markdown]
# 表示を消す

# %%
rb.clear()

# %% [markdown]
# ロボットの表示を隠す

# %%
rb.hideRobot()

# %% [markdown]
# ロボットを表示する

# %%
rb.showRobot()

# %% [markdown]
# <ロボットを動かす>
#
# ロボットの関節を初期化する

# %%
rb.resetRobot()

# %% [raw]
# ## WARECを見る

# %%
fname=iu.parseURL('choreonoid://share/model/WAREC1/WAREC1.body')
rb=RobotBuilder(robot=fname)

# %% [markdown]
# viewAll / 全体が見える位置にカメラを移動

# %%
rb.draw.viewAll()

# %% [markdown]
# ビジュアライズ

# %%
rb.viewInfo(scale=0.04)
# Out:
# [Wrap: <coordinates[0x55e025624ac0] 0 0 0 / 0 0.707107 0 0.707107 > | <cnoid.Util.SgPosTransform object at 0x7fa4775da6b0>, Wrap: <coordinates[0x55e025640ea0] -5e-06 0.164905 -3.06162e-22 / 0 0.707107 0 0.707107 > | <cnoid.Util.SgPosTransform object at 0x7fa4775da5b0>, Wrap: <coordinates[0x55e0334093c0] -0.169005 0.164905 -1.03486e-17 / 0 0.707107 0 0.707107 > | <cnoid.Util.SgPosTransform object at 0x7fa4775da530>, Wrap: <coordinates[0x55e033351dc0] -0.410005 0.164905 -2.51056e-17 / 0 0.707107 0 0.707107 > | <cnoid.Util.SgPosTransform object at 0x7fa4775da8f0>, Wrap: <coordinates[0x55e02563a390] -0.488045 0.164905 -0.046 / 0 0.707107 0 0.707107 > | <cnoid.Util.SgPosTransform object at 0x7fa4775da8b0>, Wrap: <coordinates[0x55e02566b790] -0.701045 0.164905 -4.85723e-17 / 0 0.707107 0 0.707107 > | <cnoid.Util.SgPosTransform object at 0x7fa4775da870>, Wrap: <coordinates[0x55e0254d0970] -0.781045 0.164905 -5.34708e-17 / 0 0.707107 0 0.707107 > | <cnoid.Util.SgPosTransform object at 0x7fa4
# ...

# %% [markdown]
# 画面表示

# %%
# %display
